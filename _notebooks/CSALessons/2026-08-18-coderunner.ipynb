# %%
---
layout: post
toc: true
codemirror: true
title: Game Runner
description: n/a
permalink: /csalessons/coderunner
---

# %% [markdown]
# ## Imbedding code runners within your notebook
#
# ```liquid
# {% raw %}{% include runners/code.html runner_id="your-runner-id" language="your-language" code=your_code_variable %}{% endraw %}
# ```
#
# ## Example for Python:
#
# ```liquid
# {% raw %}{% include runners/code.html runner_id="python-main" language="python" code=python_example %}{% endraw %}
# ```
#
# ## Clearing the output:
#
# ```javascript
# outputElement.innerHTML = '';
# ```
#
# ## Canvas:
#
# ```javascript
# const canvas = document.createElement('canvas');
# canvas.width = 400;
# canvas.height = 400;
# outputElement.appendChild(canvas);
# const ctx = canvas.getContext('2d');
# ```
#
# LOCAL TEST 123456
#
# ## Visit [here](http://127.0.0.1:4500/katherine_2027/gamerunner/) to learn more:
