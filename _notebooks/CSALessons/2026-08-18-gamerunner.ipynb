# %%
---
layout: post
toc: true
codemirror: true
title: Game Runner
description: n/a
permalink: /csalessons/gamerunner
---

# %% [markdown]
# ### Imbedding code runners within your notebook
# > Use <strong>{% include runners/code.html runner_id="your-runner-id" language="your-language" code=your_code_variable %} </strong>
# - Example for Python: <em> {% include runners/code.html runner_id="python-main" language="python" code=python_example %} </em>
